# %%
import xlrd
import pandas as pd
import os
from pandas import *
from IPython.display import display
import matplotlib
from googletrans import Translator

# %%
# load excel file
file_path = os.path.join('Client_info_Translated_4.xlsx')
file_path2 = os.path.join('Province_List.xlsx')
# read the excel file
df  = pd.read_excel(file_path, sheet_name=None, ignore_index=True)
df2  = pd.read_excel(file_path2, sheet_name=None, ignore_index=True)
# concatenate all worksheets
cdf = pd.concat(df.values())
cdf2= pd.concat(df2.values())

# %%
# display consolidated data
cdf.head()
# Out:
#   Client ID Client Category  \
# 0    DL1001              DL
# 1    DL1002              DL
# 2    DL1003              DL
# 3    DL1004              DL
# 4    DL1005              DL
#
#                                           Address_EN      Name_EN
# 0  Chongqing Yuzhong District Hualong Bridge Chon...        HELEN
# 1  Qingshui Bay, Zhangjiagang City, Jiangsu Provi...        irene
# 2  Zhang Xu Receives 186 6397 5770\nShandong Prov...      J ing.Z
# 3  7-2-301, Liuheyuan Garden, Fuxing Road, Shangc...   Rain-agent
# 4  No.2 Unit 26E, Building 6A, Laijing Bay, Indus...  Sara agency

# %%
# display consolidated data
cdf2
# Out:
#          Provinces
# 0            Anhui
# 1           Fujian
# 2            Gansu
# 3        Guangdong
# 4          Guizhou
# 5           Hainan
# 6            Hebei
# 7     Heilongjiang
# 8            Henan
# 9            Hubei
# 10           Hunan
# 11         Jiangsu
# 12         Jiangxi
# 13           Jilin
# 14        Liaoning
# 15         Qinghai
# 16         Shaanxi
# 17        Shandong
# 18          Shanxi
# 19         Sichuan
# 20          Yunnan
# 21        Zhejiang
# 22         Guangxi
# 23  Inner Mongolia
# 24         Ningxia
# 25           Tibet
# 26        Xinjiang
# 27         Beijing
# 28         Tianjin
# 29        Shanghai
# 30       Chongqing
# 31        HongKong
# 32           Macao
# 33          Taiwan

# %%
Provinces = cdf2['Provinces'].tolist()
cdf['Address_EN'] = cdf['Address_EN'].str.replace('[^\w\s]',' ')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Shenzhen','Shenzhen Guangdong')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Guangzhou','Guangzhou Guangdong')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Fuzhou','Fuzhou Fujian')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Quanzhou','Quanzhou Fujian')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Wuhan','Wuhan Hubei')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Jingzhou','Jingzhou Hubei')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Guilin','Guilin Guangxi')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Hefei','Hefei Anhui')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Nanjing','Nanjing Jiangsu')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Hangzhou','Hangzhou Zhejiang')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Qingdao','Qingdao Shandong')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Harbin','Harbin Heilongjiang')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Xiamen','Xiamen Fujian')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Xi an','Xi an Shaanxi')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Taiyuan','Taiyuan Shanxi')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Chengdu','Chengdu Sichuan')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Pudong','Pudong Shanghai')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Shenyang','Shenyang Liaoning')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Nanchang','Nanchang Jiangxi')

cdf['Address_EN'] = cdf['Address_EN'].str.replace('Changsha','Changsha Hunan')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Lanzhou','Lanzhou Gansu')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('21 Dongzhimenwai Avenue','21 Dongzhimenwai Avenue Beijing')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Tangshan','Tangshan Hebei')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Suzhou','Suzhou Jiangsu')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Guiyang','Guiyang Guizhou')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Changchun','Changchun Jilin')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Chaoyang District No  6 Chaowai Outer Soho Block D 0937 Ou Peng Browser','Beijing No  6 Chaowai Outer Soho Block D 0937 Ou Peng Browser')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Xicheng District  China Weapons Zhang','Beijing Xicheng District  China Weapons Zhang ')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Jinan','Jinan Shandong')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Changsha','Changsha Hunan')

cdf['Address_EN'] = cdf['Address_EN'].str.replace('Beihai','Beihai Guangxi')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Xicheng District  Anxingrong ','Beijing Xicheng District  Anxingrong ')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('No 6 Broadcast Road','Beijing No 6 Broadcast Road')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Yancheng','Yancheng Jiangsu')

cdf['Address_EN'] = cdf['Address_EN'].str.replace('Chaoyang District No  19  Chaoyang Street  Huapu','Beijing Chaoyang District No  19  Chaoyang Street  Huapu')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Lanzhou','Lanzhou Gansu')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('21 Dongzhimenwai Avenue','21 Dongzhimenwai Avenue Beijing')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Chaoyang District Liufang North Street','Beijing Chaoyang District Liufang North Street')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('Hong Kong','Hong Kong Hongkong HK')

cdf['Address_EN'] = cdf['Address_EN'].str.replace('San Francisco  CA 94102','San Francisco  CA 94102 US')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('NJ 07310','NJ 07310 US')
cdf['Address_EN'] = cdf['Address_EN'].str.replace('San Francisco  CA 94102','San Francisco  CA 94102 US')

address_list = cdf['Address_EN']

# %%
address_list[4].split()
# Out:
# ['No',
#  '2',
#  'Unit',
#  '26E',
#  'Building',
#  '6A',
#  'Laijing',
#  'Bay',
#  'Industrial',
#  '7th',
#  'Road',
#  'Nanshan',
#  'District',
#  'Shenzhen',
#  'Guangdong',
#  'China',
#  'Song',
#  'Jia',
#  '18520805713']

# %%
province_list = []

for addr in address_list:
    prov = 'NaN'
    for char in addr.split():
        if char in Provinces:
            prov = char
            break
        else: 
            continue
    province_list.append(prov)
            
#             break
#     else:
#         continue    
#     break
    
            
#         
province_list
# Out:
# ['Chongqing',
#  'Jiangsu',
#  'Shandong',
#  'Zhejiang',
#  'Guangdong',
#  'Hubei',
#  'Hubei',
#  'Zhejiang',
#  'NaN',
#  'Guangdong',
#  'Zhejiang',
#  'NaN',
#  'Shanghai',
#  'Tianjin',
#  'Hebei',
#  'Sichuan',
#  'Guangdong',
#  'Zhejiang',
#  'Fujian',
#  'Shanghai',
#  'NaN',
#  'NaN',
#  'Shandong',
#  'Beijing',
#  'Hebei',
#  'Beijing',
#  'Sichuan',
#  'Beijing',
#  'Beijing',
#  'Shanghai',
#  'Beijing',
#  'NaN',
#  'Beijing',
#  'Hubei',
#  'Beijing',
#  'Beijing',
#  'Anhui',
#  'Hubei',
#  'Sichuan',
#  'Beijing',
#  'Beijing',
#  'Beijing',
#  'Beijing',
#  'Guangdong',
#  'Shanxi',
#  'Sichuan',
#  'Beijing',
#  'Shanxi',
#  'Hubei',
#  'Hubei',
#  'Shanghai',
#  'Beijing',
#  'Beijing',
#  'Shanghai',
#  'Sichuan',
#  'Beijing',
#  'Hubei',
#  'Beijing',
#  'Shanghai',
#  'Sichuan',
#  'Beijing',
#  'Sichuan',
#  'Beijing',
#  'Shanghai',
#  'Sichuan',
#  'Zhejiang',
#  'Shanghai',
#  'Sichuan',
#  'Beijing',
#  'Beijing',
#  'Yunnan',
#  'Shaanxi',
# ...

# %%
len(province_list)
# Out:
# 1394

# %%
len(address_list)
# Out:
# 1394

# %%
cdf['Province']= province_list
cdf.head()
# Out:
#   Client ID Client Category  \
# 0    DL1001              DL
# 1    DL1002              DL
# 2    DL1003              DL
# 3    DL1004              DL
# 4    DL1005              DL
#
#                                           Address_EN      Name_EN   Province
# 0  Chongqing Yuzhong District Hualong Bridge Chon...        HELEN  Chongqing
# 1  Qingshui Bay  Zhangjiagang City  Jiangsu Provi...        irene    Jiangsu
# 2  Zhang Xu Receives 186 6397 5770\nShandong Prov...      J ing.Z   Shandong
# 3  7 2 301  Liuheyuan Garden  Fuxing Road  Shangc...   Rain-agent   Zhejiang
# 4  No 2 Unit 26E  Building 6A  Laijing Bay  Indus...  Sara agency  Guangdong

# %%
writer = pd.ExcelWriter('Client_info_Translated_7.xlsx')
cdf.to_excel(writer,'Sheet1')
