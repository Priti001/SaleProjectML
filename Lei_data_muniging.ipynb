# %% [markdown]
# ## Lei Data Munging

# %%
# General Dependencies

import numpy as np
import pandas as pd
import datetime as dt

# %%
# Read the data
df_original = pd.read_csv('data/Sales_Data.csv')
print('Dataframe dimensions:', df_original.shape)
# Out:
# Dataframe dimensions: (1884, 24)

# %%
df_original.head(10)
# Out:
#   Stock ID  Order Priority  Cost of Goods  Unit Price  Shipping Cost  \
# 0   171001             NaN          720.0         900            0.0
# 1   171002             NaN          165.6         207            0.0
# 2   171003             NaN           76.0          99           15.0
# 3   171004             NaN           87.0         120           22.5
# 4   171005             NaN           87.0         120           22.5
# 5   171006             NaN          113.0         193           15.0
# 6   171007             NaN           33.0         107           15.0
# 7   171008             NaN           33.0         107           15.0
# 8   171009             NaN           33.0         107           15.0
# 9   171010             NaN           36.0          64            7.5
#
#   Customer ID Customer Name  Vendor Order Status (Backorder?)  \
# 0       L1784           NaN   V1011                 Backorder
# 1     VIP1023           NaN  DIRECT                 Backorder
# 2    VVIP1017           NaN  DIRECT                  finished
# 3       L1631           NaN  DIRECT                  finished
# 4       L1631           NaN  DIRECT                  finished
# 5       H1270           NaN  DIRECT                  finished
# 6       L1609           NaN  DIRECT                  finished
# 7       L1367           NaN  DIRECT                  finished
# 8    VVIP1017           NaN  DIRECT                  finished
# 9       L1126           NaN  DIRECT                  finished
#
#   Product Category    ...    Region  State or Province City Postal Code  \
# 0         Clothing    ...       NaN                NaN  NaN         NaN
# 1            Shoes    ...       NaN                NaN  NaN         NaN
# 2         Clothing    ...       NaN                NaN  NaN         NaN
# 3            Shoes    ...       NaN                NaN  NaN         NaN
# 4            Shoes    ...       NaN                NaN  NaN         NaN
# 5         Clothing    ...       NaN                NaN  NaN         NaN
# 6         Clothing    ...       NaN                NaN  NaN         NaN
# 7         Clothing    ...       NaN                NaN  NaN         NaN
# 8         Clothing    ...       NaN                NaN  NaN         NaN
# 9         Clothing    ...       NaN                NaN  NaN         NaN
#
#    Order Date  Ship Date Profit  Quantity ordered new Sales  Order ID
# 0   1/17/2017        NaN  180.0                   1.0   900   2017011
# 1   1/17/2017        NaN   41.4                   1.0   207   2017012
# 2   1/17/2017        NaN    8.0                   1.0    99   2017013
# 3   1/17/2017        NaN   10.5                   1.0   120   2017014
# 4   1/17/2017        NaN   10.5                   1.0   120   2017015
# 5   1/17/2017        NaN   65.0                   1.0   193   2017016
# 6   1/17/2017        NaN   59.0                   1.0   107   2017017
# 7   1/17/2017        NaN   59.0                   1.0   107   2017018
# 8   1/17/2017        NaN   59.0                   1.0   107   2017019
# 9   1/17/2017        NaN   20.5                   1.0    64  20170110
#
# [10 rows x 24 columns]

# %%
def num_missing(x):
  return sum(x.isnull())

# %%
# How many NAN values per column with have.

# Applying per column:
print (f"Missing values per column in df_customers :\n{df_original.apply(num_missing, axis=0)}")
# Out:
# Missing values per column in df_customers :
# Stock ID                           1
# Order Priority                  1884
# Cost of Goods                      0
# Unit Price                         0
# Shipping Cost                      0
# Customer ID                        0
# Customer Name                   1882
# Vendor                             0
# Order Status (Backorder?)          0
# Product Category                   0
# Product Sub-Category / Brand       0
# Product Container               1884
# Product_Name_EN                    0
# Product Base Margin               80
# Region                          1884
# State or Province               1884
# City                            1883
# Postal Code                     1884
# Order Date                         0
# Ship Date                       1884
# Profit                             0
# Quantity ordered new               4
# Sales                              0
# Order ID                           1
# dtype: int64

# %%
# Removing columns not necessary for Customer Segmentation by Age
list_cols_drop = ['Order Priority', 'Customer Name', 'Product Container', 'Region', 'State or Province', 'City',
                  'Postal Code', 'Ship Date']
df_data= df_original.drop(list_cols_drop, axis=1)

# %%
#remove rows where StockID, "Quantity ordered new" , OrderID are NA
df_data.dropna(subset=['Stock ID'],how='all',inplace=True)
df_data.dropna(subset=['Order ID'],how='all',inplace=True)
df_data.dropna(subset=['Quantity ordered new'],how='all',inplace=True)
df_data.shape
# Out:
# (1878, 16)

# %%
df_data.columns
# Out:
# Index(['Stock ID', 'Cost of Goods', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Vendor', 'Order Status (Backorder?)',
#        'Product Category', 'Product Sub-Category / Brand', 'Product_Name_EN',
#        'Product Base Margin', 'Order Date', 'Profit', 'Quantity ordered new',
#        'Sales', 'Order ID'],
#       dtype='object')

# %%
# Rename columns

df_data.rename(columns={"Product Sub-Category / Brand": 'Brand','Product_Name_EN': 'Product Description', 
                                  'Quantity ordered new': 'Quantity'}, inplace=True)

df_data.head()
# Out:
#   Stock ID  Cost of Goods  Unit Price  Shipping Cost Customer ID  Vendor  \
# 0   171001          720.0         900            0.0       L1784   V1011
# 1   171002          165.6         207            0.0     VIP1023  DIRECT
# 2   171003           76.0          99           15.0    VVIP1017  DIRECT
# 3   171004           87.0         120           22.5       L1631  DIRECT
# 4   171005           87.0         120           22.5       L1631  DIRECT
#
#   Order Status (Backorder?) Product Category         Brand  \
# 0                 Backorder         Clothing  Canada Goose
# 1                 Backorder            Shoes         Vince
# 2                  finished         Clothing      Madewell
# 3                  finished            Shoes           UGG
# 4                  finished            Shoes           UGG
#
#                                  Product Description Product Base Margin  \
# 0                      Canada goose trillium black s                 20%
# 1              Vince polette suede high heel black 6                 20%
# 2  Madewell Trevi Drapey Blazer Suit Black 2 Last...                  8%
# 3  UGG Australia – Joey Leather & Genuine Shearli...                  9%
# 4                          Ugg red short paragraph 7                  9%
#
#   Order Date  Profit  Quantity  Sales Order ID
# 0  1/17/2017   180.0       1.0    900  2017011
# 1  1/17/2017    41.4       1.0    207  2017012
# 2  1/17/2017     8.0       1.0     99  2017013
# 3  1/17/2017    10.5       1.0    120  2017014
# 4  1/17/2017    10.5       1.0    120  2017015

# %%
# If Profit is negative, change to NaN. 
df_data[df_data['Profit'] < 0] = np.nan

# If Product Base Margin is Nan, change to 0.

df_data['Product Base Margin'].fillna(0)
# Out:
# 0       20%
# 1       20%
# 2        8%
# 3        9%
# 4        9%
# 5       34%
# 6       55%
# 7       55%
# 8       55%
# 9       32%
# 10      55%
# 11      52%
# 12      22%
# 13       7%
# 14      43%
# 15      55%
# 16      46%
# 17      43%
# 18      43%
# 19      32%
# 20      22%
# 21      54%
# 22      54%
# 23        0
# 24      66%
# 25      54%
# 26      54%
# 27      39%
# 28      45%
# 29      21%
#        ...
# 1854    31%
# 1855     5%
# 1856     4%
# 1857    19%
# 1858    23%
# 1859    19%
# 1860    34%
# 1861    32%
# 1862    30%
# 1863    32%
# 1864    11%
# 1865    28%
# 1866    15%
# 1867    11%
# 1868    26%
# 1869    11%
# 1870    11%
# 1871    21%
# 1872    33%
# 1873    13%
# 1874    23%
# 1875    15%
# 1876      0
# 1877    20%
# 1878    19%
# 1879    19%
# 1880    19%
# 1881    45%
# 1882    39%
# 1883    46%
# Name: Product Base Margin, Length: 1878, dtype: object

# %%
# Total of orders, customers, products and brands

pd.DataFrame([{'orders': len(df_data['Order ID'].value_counts()),    
               'customers': len(df_data['Customer ID'].value_counts()),
               'products': len(df_data['Product Description'].value_counts()), 
               'total of brands' : len(df_data.Brand.unique())
              }], columns = ['orders', 'customers', 'products','total of brands'], index = ['quantity'])
# Out:
#           orders  customers  products  total of brands
# quantity    1843        594      1564              142

# %%
df_data.describe()
# Out:
#        Cost of Goods    Unit Price  Shipping Cost        Profit     Quantity  \
# count    1849.000000   1849.000000    1849.000000   1849.000000  1849.000000
# mean      198.729638    275.190373      11.065928    104.280530     0.976203
# std       648.244509    995.698451      12.189854   1531.320663     0.321449
# min         1.000000     21.000000       0.000000      0.000000     0.000000
# 25%        52.000000     86.000000       5.000000     20.000000     1.000000
# 50%       101.000000    154.000000       7.500000     35.500000     1.000000
# 75%       188.000000    254.000000      15.000000     57.500000     1.000000
# max     15816.000000  26360.000000     300.000000  50410.000000    10.000000
#
#                Sales
# count    1849.000000
# mean      365.299081
# std      3864.958628
# min         0.000000
# 25%        79.000000
# 50%       146.000000
# 75%       241.000000
# max    126650.000000

# %%
# df_data['Order Date'] = pd.to_datetime(pd.Series(['05/23/2005']), format="%d/%d/%Y")
df_data['Order Date'] = pd.to_datetime(df_data['Order Date'])

# Get month and year
df_data['Day'] = df_data['Order Date'].dt.day
df_data['Month'] = df_data['Order Date'].dt.month
df_data['Year'] = df_data['Order Date'].dt.year

df_data.count()
# Out:
# Stock ID                     1849
# Cost of Goods                1849
# Unit Price                   1849
# Shipping Cost                1849
# Customer ID                  1849
# Vendor                       1849
# Order Status (Backorder?)    1849
# Product Category             1849
# Brand                        1849
# Product Description          1849
# Product Base Margin          1779
# Order Date                   1849
# Profit                       1849
# Quantity                     1849
# Sales                        1849
# Order ID                     1849
# Day                          1849
# Month                        1849
# Year                         1849
# dtype: int64

# %%
# Save clean data for work with Customer and Brand 
df_data.to_csv('data/data_ready.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-14-93ef3ed2f963> in <module>()
#       1 # Save clean data for work with Customer and Brand
# ----> 2 df_data.to_csv('data/data_ready.csv',index=False)
#
# c:\users\bea\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# c:\users\bea\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# c:\users\bea\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'data/data_ready.csv'
