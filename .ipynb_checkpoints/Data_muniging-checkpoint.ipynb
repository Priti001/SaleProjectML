# %% [markdown]
# ## Lei Data Munging

# %%
# General Dependencies

import numpy as np
import pandas as pd
import datetime as dt

# %%
# Read the data
# df_original = pd.read_csv('data/Sales_Data.csv')
df_original = pd.read_csv('data/Clean_Data_Translated_5.csv')
print('Dataframe dimensions:', df_original.shape)
# Out:
# Dataframe dimensions: (1884, 24)

# %%
df_original.head(10)
# Out:
#   Stock ID  Order Priority  Cost of Goods  Unit Price  Shipping Cost  \
# 0   171001             NaN          720.0       900.0            0.0
# 1   171002             NaN          165.6       207.0            0.0
# 2   171003             NaN           76.0        99.0           15.0
# 3   171004             NaN           87.0       120.0           22.5
# 4   171005             NaN           87.0       120.0           22.5
# 5   171006             NaN          113.0       193.0           15.0
# 6   171007             NaN           33.0       107.0           15.0
# 7   171008             NaN           33.0       107.0           15.0
# 8   171009             NaN           33.0       107.0           15.0
# 9   171010             NaN           36.0        64.0            7.5
#
#   Customer ID Customer Name  Vendor Order Status (Backorder?)  \
# 0       L1784           NaN   V1011                 Backorder
# 1     VIP1023           NaN  DIRECT                 Backorder
# 2    VVIP1017           NaN  DIRECT                  finished
# 3       L1631           NaN  DIRECT                  finished
# 4       L1631           NaN  DIRECT                  finished
# 5       H1270           NaN  DIRECT                  finished
# 6       L1609           NaN  DIRECT                  finished
# 7       L1367           NaN  DIRECT                  finished
# 8    VVIP1017           NaN  DIRECT                  finished
# 9       L1126           NaN  DIRECT                  finished
#
#   Product Category    ...    Region  State or Province City Postal Code  \
# 0         Clothing    ...       NaN                NaN  NaN         NaN
# 1            Shoes    ...       NaN                NaN  NaN         NaN
# 2         Clothing    ...       NaN                NaN  NaN         NaN
# 3            Shoes    ...       NaN                NaN  NaN         NaN
# 4            Shoes    ...       NaN                NaN  NaN         NaN
# 5         Clothing    ...       NaN                NaN  NaN         NaN
# 6         Clothing    ...       NaN                NaN  NaN         NaN
# 7         Clothing    ...       NaN                NaN  NaN         NaN
# 8         Clothing    ...       NaN                NaN  NaN         NaN
# 9         Clothing    ...       NaN                NaN  NaN         NaN
#
#    Order Date  Ship Date Profit  Quantity ordered new  Sales  Order ID
# 0      Jan-17        NaN  180.0                   1.0  900.0   2017011
# 1      Jan-17        NaN   41.4                   1.0  207.0   2017012
# 2      Jan-17        NaN    8.0                   1.0   99.0   2017013
# 3      Jan-17        NaN   10.5                   1.0  120.0   2017014
# 4      Jan-17        NaN   10.5                   1.0  120.0   2017015
# 5      Jan-17        NaN   65.0                   1.0  193.0   2017016
# 6      Jan-17        NaN   59.0                   1.0  107.0   2017017
# 7      Jan-17        NaN   59.0                   1.0  107.0   2017018
# 8      Jan-17        NaN   59.0                   1.0  107.0   2017019
# 9      Jan-17        NaN   20.5                   1.0   64.0  20170110
#
# [10 rows x 24 columns]

# %%
def num_missing(x):
  return sum(x.isnull())

# %%
# How many NAN values per column with have.

# Applying per column:
print (f"Missing values per column in df_customers :\n{df_original.apply(num_missing, axis=0)}")
# Out:
# Missing values per column in df_customers :
# Stock ID                           1
# Order Priority                  1884
# Cost of Goods                      0
# Unit Price                         0
# Shipping Cost                      0
# Customer ID                        0
# Customer Name                   1882
# Vendor                             0
# Order Status (Backorder?)          0
# Product Category                   0
# Product Sub-Category / Brand       0
# Product Container               1884
# Product_Name_EN                    0
# Product Base Margin               80
# Region                          1884
# State or Province               1884
# City                            1883
# Postal Code                     1884
# Order Date                         0
# Ship Date                       1884
# Profit                             0
# Quantity ordered new               4
# Sales                              0
# Order ID                           1
# dtype: int64

# %%
# Removing columns not necessary for Customer Segmentation 

list_cols_drop = ['Order Priority', 'Customer Name', 'Product Container', 'Region', 'State or Province', 'City',
                  'Postal Code', 'Ship Date']
df_data= df_original.drop(list_cols_drop, axis=1)

# %%
#remove rows where StockID, "Quantity ordered new" , OrderID are NaN 

df_data.dropna(subset=['Stock ID'],how='all',inplace=True)
df_data.dropna(subset=['Order ID'],how='all',inplace=True)
df_data.dropna(subset=['Quantity ordered new'],how='all',inplace=True)
df_data.shape
# Out:
# (1878, 16)

# %%
df_data.columns
# Out:
# Index(['Stock ID', 'Cost of Goods', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Vendor', 'Order Status (Backorder?)',
#        'Product Category', 'Product Sub-Category / Brand', 'Product_Name_EN',
#        'Product Base Margin', 'Order Date', 'Profit', 'Quantity ordered new',
#        'Sales', 'Order ID'],
#       dtype='object')

# %%
# Rename columns
df_data.rename(columns={"Product Sub-Category / Brand": 'Brand','Product_Name_EN': 'Product Description', 
                         'Order Status (Backorder?)': 'Order Status', 'Quantity ordered new': 'Quantity'}, inplace=True)

df_data.head()
# Out:
#   Stock ID  Cost of Goods  Unit Price  Shipping Cost Customer ID  Vendor  \
# 0   171001          720.0       900.0            0.0       L1784   V1011
# 1   171002          165.6       207.0            0.0     VIP1023  DIRECT
# 2   171003           76.0        99.0           15.0    VVIP1017  DIRECT
# 3   171004           87.0       120.0           22.5       L1631  DIRECT
# 4   171005           87.0       120.0           22.5       L1631  DIRECT
#
#   Order Status Product Category         Brand  \
# 0    Backorder         Clothing  Canada Goose
# 1    Backorder            Shoes         Vince
# 2     finished         Clothing      Madewell
# 3     finished            Shoes           UGG
# 4     finished            Shoes           UGG
#
#                                  Product Description Product Base Margin  \
# 0                      Canada goose trillium black s                 20%
# 1              Vince polette suede high heel black 6                 20%
# 2  Madewell Trevi Drapey Blazer Suit Black 2 Last...                  8%
# 3  UGG Australia – Joey Leather & Genuine Shearli...                  9%
# 4                          Ugg red short paragraph 7                  9%
#
#   Order Date  Profit  Quantity  Sales Order ID
# 0     Jan-17   180.0       1.0  900.0  2017011
# 1     Jan-17    41.4       1.0  207.0  2017012
# 2     Jan-17     8.0       1.0   99.0  2017013
# 3     Jan-17    10.5       1.0  120.0  2017014
# 4     Jan-17    10.5       1.0  120.0  2017015

# %%
# REMOVE OUTLIERS 

# If Order Status is Backorder.
df_data = df_data[(df_data['Order Status'] != 'Backorder')]
df_data = df_data[(df_data.Quantity > 0 )]
# df_data = df_data[(df_data['Cost of Goods'] < 10000)]

# %%
df_data
# Out:
#      Stock ID  Cost of Goods  Unit Price  Shipping Cost Customer ID  Vendor  \
# 1876                               gm black peter Black                 -1%
# 1877                      lamer / lp / chantecaille etc                 20%
# 1878                      lamer / lp / chantecaille etc                 19%
# 1879                                 Spring Season * 20                 19%
# 1880                                 Spring Season * 40                 19%
# 1881              Winter Shoe Discount Whole Sale Event                 45%
# 1882              Winter Shoe Discount Whole Sale Event                 39%
# 1883              Winter Shoe Discount Whole Sale Event                 46%
#
#      Order Date  Profit  Quantity    Sales   Order ID
# 2        Jan-17     8.0       1.0     99.0    2017013
# 3        Jan-17    10.5       1.0    120.0    2017014
# 4        Jan-17    10.5       1.0    120.0    2017015
# 5        Jan-17    65.0       1.0    193.0    2017016
# 6        Jan-17    59.0       1.0    107.0    2017017
# 7        Jan-17    59.0       1.0    107.0    2017018
# 8        Jan-17    59.0       1.0    107.0    2017019
# 9        Jan-17    20.5       1.0     64.0   20170110
# 10       Jan-17    59.0       1.0    107.0   20170111
# 11       Jan-17    41.5       1.0     80.0   20170112
# 12       Jan-17    17.0       1.0     76.0   20170113
# 13       Jan-17    51.0       1.0    743.0   20170114
# 14       Jan-17    34.0       1.0     80.0   20170115
# 15       Jan-17    59.0       1.0    107.0   20170116
# 16       Jan-17    46.0       1.0     99.0   20170117
# 17       Jan-17    68.5       1.0    161.0   20170118
# 18       Jan-17    34.5       1.0     80.0   20170119
# 19       Jan-17    20.5       1.0     64.0   20170120
# 20       Jan-17    28.0       1.0    127.0   20170121
# 21       Jan-17    53.0       1.0     99.0   20170122
# 22       Jan-17    53.0       1.0     99.0   20170123
# 23       Jan-17   -23.0       1.0    541.0   20170124
# 24       Jan-17   150.0       1.0    226.0   20170125
# 25       Jan-17   138.0       1.0    256.0   20170126
# 26       Jan-17   138.0       1.0    256.0   20170127
# 27       Jan-17    72.0       1.0    183.0   20170128
# 28       Jan-17    24.5       1.0     54.0   20170129
# 29       Jan-17    23.5       1.0    111.0   20170130
# 30       Jan-17     0.8       1.0     79.0   20170131
# 31       Jan-17     0.8       1.0     79.0   20170132
# ...         ...     ...       ...      ...        ...
# 1854     Mar-18    81.0       1.0    258.0  201803080
# 1855     Mar-18     7.0       1.0    155.0  201803081
# 1856     Mar-18     6.0       1.0    155.0  201803082
# 1857     Mar-18    30.0       1.0    155.0  201803083
# 1858     Mar-18    72.0       1.0    309.0  201803084
# 1859     Mar-18    29.0       1.0    155.0  201803085
# 1860     Mar-18    96.0       1.0    286.0  201803086
# 1861     Mar-18    86.0       1.0    273.0  201803087
# 1862     Mar-18    79.0       1.0    266.0  201803088
# 1863     Mar-18    49.0       1.0    155.0  201803089
# 1864     Mar-18    26.0       1.0    233.0  201803091
# 1865     Mar-18    60.0       1.0    216.0  201803092
# 1866     Mar-18    30.0       1.0    195.0  201803093
# 1867     Mar-18    24.0       1.0    227.0  201803094
# 1868     Mar-18   112.0       1.0    438.0  201803095
# 1869     Mar-18   159.0       1.0   1477.0  201803097
# 1870     Mar-18    33.0       1.0    311.0  201803098
# 1871     Mar-18    55.0       1.0    258.0  201803099
# 1872     Mar-18    49.0       1.0    148.0  201803100
# 1873     Mar-18    34.0       1.0    258.0  201803101
# 1874     Mar-18    47.0       1.0    203.0  201803102
# 1875     Mar-18   875.0       1.0   5870.0  201803103
# 1876     Mar-18    -2.0       1.0    148.0  201803104
# 1877     Mar-18  3050.0       1.0  15370.0  201803105
# 1878     Mar-18   320.6       1.0   1703.0  201803112
# 1879     Mar-18   320.6       1.0   1703.0  201803112
# 1880     Mar-18   661.2       1.0   3406.0  201803114
# 1881     Mar-18  2163.0       1.0   4813.0  201803115
# 1882     Mar-18  1904.0       1.0   4844.0  201803116
# 1883     Mar-18  2519.0       1.0   5469.0  201803117
#
# [1781 rows x 16 columns]

# %%
# If Profit is negative, change to NaN. 
df_data[df_data['Profit'] < 0] = np.nan

# If Product Base Margin is Nan, change to 0.

df_data['Product Base Margin'].fillna(0)

df_data.shape
# Out:
# (1781, 16)

# %%
# Total of orders, customers, products and brands

pd.DataFrame([{'orders': len(df_data['Order ID'].value_counts()),    
               'customers': len(df_data['Customer ID'].value_counts()),
               'products': len(df_data['Product Description'].value_counts()), 
               'total of brands' : len(df_data.Brand.unique())
              }], columns = ['orders', 'customers', 'products','total of brands'], index = ['quantity'])
# Out:
#           orders  customers  products  total of brands
# quantity    1748        579      1482              138

# %%
df_data.describe()
# Out:
#        Cost of Goods    Unit Price  Shipping Cost        Profit     Quantity  \
# count    1752.000000   1752.000000    1752.000000   1752.000000  1752.000000
# mean      194.390068    272.300799      11.678596    108.911587     1.014840
# std       659.744627   1017.602449      12.233762   1572.992276     0.263541
# min         1.000000     21.000000       0.000000      0.000000     1.000000
# 25%        49.000000     84.000000       7.500000     22.450000     1.000000
# 50%       100.000000    151.500000       7.500000     36.500000     1.000000
# 75%       184.000000    250.000000      15.000000     59.000000     1.000000
# max     15816.000000  26360.000000     300.000000  50410.000000    10.000000
#
#                Sales
# count    1752.000000
# mean      380.446347
# std      3969.624712
# min        21.000000
# 25%        84.000000
# 50%       152.500000
# 75%       250.000000
# max    126650.000000

# %%
# Format 'Order Date' column.
df_data['Order Date'] = pd.to_datetime(df_data['Order Date'], format="%b-%y")
df_data['Order Date'] = df_data['Order Date'].dt.strftime('%m/%d/%Y')
df_data['Order Date'] = pd.to_datetime(df_data['Order Date'], format='%m/%d/%Y')

print(df_data['Order Date'].head())
# Out:
# 2   2017-01-01
# 3   2017-01-01
# 4   2017-01-01
# 5   2017-01-01
# 6   2017-01-01
# Name: Order Date, dtype: datetime64[ns]

# %%
# Get month and year
df_data['Month'] = df_data['Order Date'].dt.month
df_data['Year'] = df_data['Order Date'].dt.year

df_data.count()
# Out:
# Stock ID               1752
# Cost of Goods          1752
# Unit Price             1752
# Shipping Cost          1752
# Customer ID            1752
# Vendor                 1752
# Order Status           1752
# Product Category       1752
# Brand                  1752
# Product Description    1752
# Product Base Margin    1752
# Order Date             1752
# Profit                 1752
# Quantity               1752
# Sales                  1752
# Order ID               1752
# Month                  1752
# Year                   1752
# dtype: int64

# %%
# Save clean data for work with Customer and Brand 
df_data.to_csv('data/data_ready.csv',index=False)
