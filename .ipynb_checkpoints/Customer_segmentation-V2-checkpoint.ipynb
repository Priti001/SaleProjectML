# %% [markdown]
# # Customer Segmentation

# %%
# General Dependencies

import numpy as np
import pandas as pd
import matplotlib as mpl
import pylab as pl

# Visualizations

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 1 - Data Engineering

# %%
# Read the data
df_origdata = pd.read_csv('data/Project_Sales_Data_Clean.csv',encoding="ISO-8859-1")
print('Dataframe dimensions:', df_origdata.shape)
# Out:
# Dataframe dimensions: (328, 20)

# %%
df_origdata.head(10)
# Out:
#     Order ID Order Date Customer ID Customer Name  Age Product Category  \
# 0  201802092   2/1/2018      DL1004          Rain   28          Handbag
# 1  201802119   2/1/2018      DL1004          Rain   28      Accessories
# 2  201803034   3/1/2018      DL1004          Rain   28      Accessories
# 3  201803035   3/1/2018      DL1004          Rain   28         Cosmetic
# 4  201803102   3/1/2018      DL1004          Rain   28      Accessories
# 5  201802122   2/1/2018      DL1005         Sarah   32         Clothing
# 6  201803089   3/1/2018      DL1005         Sarah   32            Shoes
# 7  201801037   1/1/2018      DL1007         Shine   29            Shoes
# 8  201802016   2/1/2018      DL1007         Shine   29         Cosmetic
# 9  201802081   2/1/2018      DL1007         Shine   29         Cosmetic
#
#              Brand                            Product Name      City  \
# 0      Marc Jacobs   mmj camera crossbody bag   Black grey   Beijing
# 1   Gentle Monster                             gm madcrush   Beijing
# 2   Gentle Monster                  gm madcrush sunglasses   Beijing
# 3       La Prairie                           lp gift set 2  Hangzhou
# 4   Gentle Monster                  gm sunglasses madcrush   Beijing
# 5     Alice Olivia  alice olivia katz sunburst skirt size0   Beijing
# 6  Stuart Weitzman      STUART WEITZMAN BOLSHOI SUEDE RED7   Beijing
# 7  Stuart Weitzman                       sw tiemodel Grey7   Beijing
# 8              CPB                 cpb gwp*3 + lamer gwp*1   Beijing
# 9            Lamer                       lamer gift set *3   Beijing
#
#          Lat        Long Unit Price Price Type  Quantity  Sales Revenue  \
# 0  39.904200  116.407396      $294      median          1         $294
# 1  39.904200  116.407396      $203      median          1         $203
# 2  39.904200  116.407396      $203      median          1         $203
# 3  30.274084  120.155070       $45        low           1          $45
# 4  39.904200  116.407396      $203      median          1         $203
# 5  39.904200  116.407396      $594      luxury          1         $594
# 6  39.904200  116.407396      $155      median          1         $155
# 7  39.904200  116.407396      $155      median          1         $155
# 8  39.904200  116.407396      $155      median          1         $155
# 9  39.904200  116.407396      $169      median          1         $169
#
#   Cost of Goods Shipping Cost Total Cost Gross Profit Markup Percentage
# 0         $287            $5       $292           $2              0.68%
# 1         $148            $8       $156          $47             30.13%
# 2         $148            $5       $153          $50             32.68%
# 3          $10            $8        $18          $27            150.00%
# 4         $148            $8       $156          $47             30.13%
# 5         $528            $8       $536          $58             10.82%
# 6         $101            $5       $106          $49             46.23%
# 7         $320           $23       $343        ($188)           -54.81%
# 8          $50           $15        $65          $90            138.46%
# 9          $30           $15        $45         $124            275.56%

# %%
def num_missing(x):
  return sum(x.isnull())

# %%
# How many NAN values per column with have.

# Applying per column:
print (f"Missing values per column in df_customers :\n{df_origdata.apply(num_missing, axis=0)}")

duplicated = df_origdata.duplicated(subset=['Order ID', 'Customer ID', 'Customer Name', 'Age']).sum()
print(f"Total of duplicated values in df_customers : {duplicated} ")
# Out:
# Missing values per column in df_customers :
# Order ID             0
# Order Date           0
# Customer ID          0
# Customer Name        0
# Age                  0
# Product Category     0
# Brand                0
# Product Name         0
# City                 0
# Lat                  0
# Long                 0
# Unit Price           0
# Price Type           0
# Quantity             0
# Sales Revenue        0
# Cost of Goods        0
# Shipping Cost        0
# Total Cost           0
# Gross Profit         0
# Markup Percentage    0
# dtype: int64
# Total of duplicated values in df_customers : 0

# %%
print('Dataframe df_origdata dtypes:', df_origdata.dtypes)
# Out:
# Dataframe df_origdata dtypes: Order ID               int64
# Order Date            object
# Customer ID           object
# Customer Name         object
# Age                    int64
# Product Category      object
# Brand                 object
# Product Name          object
# City                  object
# Lat                  float64
# Long                 float64
# Unit Price            object
# Price Type            object
# Quantity               int64
# Sales Revenue         object
# Cost of Goods         object
# Shipping Cost         object
# Total Cost            object
# Gross Profit          object
# Markup Percentage     object
# dtype: object

# %%
# Removing columns not necessary for Customer Segmentation by Age
list_cols_drop = ['Order Date', 'Sales Revenue', 'Cost of Goods', 'Shipping Cost', 'Total Cost', 
                  'Gross Profit', 'Markup Percentage']
df_dropcols = df_origdata.drop(list_cols_drop, axis=1)

# Show first lines
df_dropcols.head(5)
# Out:
#     Order ID Customer ID Customer Name  Age Product Category           Brand  \
# 0  201802092      DL1004          Rain   28          Handbag     Marc Jacobs
# 1  201802119      DL1004          Rain   28      Accessories  Gentle Monster
# 2  201803034      DL1004          Rain   28      Accessories  Gentle Monster
# 3  201803035      DL1004          Rain   28         Cosmetic      La Prairie
# 4  201803102      DL1004          Rain   28      Accessories  Gentle Monster
#
#                             Product Name      City        Lat        Long  \
# 0  mmj camera crossbody bag   Black grey   Beijing  39.904200  116.407396
# 1                            gm madcrush   Beijing  39.904200  116.407396
# 2                 gm madcrush sunglasses   Beijing  39.904200  116.407396
# 3                          lp gift set 2  Hangzhou  30.274084  120.155070
# 4                 gm sunglasses madcrush   Beijing  39.904200  116.407396
#
#   Unit Price Price Type  Quantity
# 0      $294      median          1
# 1      $203      median          1
# 2      $203      median          1
# 3       $45        low           1
# 4      $203      median          1

# %%
# Total of orders, customers, products and cities

pd.DataFrame([{'orders': len(df_dropcols['Order ID'].value_counts()),    
               'customers': len(df_dropcols['Customer ID'].value_counts()),
               'customers by age': len(df_dropcols['Age'].value_counts()),
               'products': len(df_dropcols['Product Name'].value_counts()), 
               'cities' : len(df_dropcols.City.unique())
              }], columns = ['orders', 'customers', 'customers by age', 'products','cities'], index = ['quantity'])
# Out:
#           orders  customers  customers by age  products  cities
# quantity     327        186                17       258       9

# %%
df_dropcols.columns
df_dropcols = df_dropcols.rename(columns={'Quantity ': 'Quantity'})
df_dropcols.sort_values('Customer ID', inplace=True)
df_dropcols
# Out:
#       Order ID Customer ID Customer Name  Age    Product Category  \
# 0    201802092      DL1004          Rain   28             Handbag
# 1    201802119      DL1004          Rain   28         Accessories
# 2    201803034      DL1004          Rain   28         Accessories
# 3    201803035      DL1004          Rain   28            Cosmetic
# 4    201803102      DL1004          Rain   28         Accessories
# 5    201802122      DL1005         Sarah   32            Clothing
# 6    201803089      DL1005         Sarah   32               Shoes
# 13   201803046      DL1007         Shine   29               Shoes
# 12   201803042      DL1007         Shine   29         Accessories
# 11   201802089      DL1007         Shine   29            Cosmetic
# 9    201802081      DL1007         Shine   29            Cosmetic
# 8    201802016      DL1007         Shine   29            Cosmetic
# 7    201801037      DL1007         Shine   29               Shoes
# 10   201802082      DL1007         Shine   29            Clothing
# 14   201802072      DL1011   Little Wood   25         Accessories
# 15   201802123      DL1012         Elisa   30            Clothing
# 16   201803076      DL1012         Elisa   30         Accessories
# 17   201803078      DL1012         Elisa   30         Accessories
# 21   201801045      DL1013         Ba Ye   33            Clothing
# 20   201801044      DL1013         Ba Ye   33            Clothing
# 19   201801031      DL1013         Ba Ye   33            Clothing
# 18   201801030      DL1013         Ba Ye   33            Clothing
# 22   201802063      DL1014            Ai   28             Handbag
# 23   201803033      DL1014            Ai   28             Handbag
# 24   201801079      DL1015          Dora   35         Accessories
# 25   201802084      DL1015          Dora   35             Handbag
# 26   201802085      DL1015          Dora   35            Clothing
# 27   201802093      DL1015          Dora   35               Shoes
# 28   201803105      DL3001   Little Wood   35  Cosmetic-wholesale
# 29   201803112      DL3002   Little Bear   35            Clothing
# ..         ...         ...           ...  ...                 ...
# 298  201803037    VVIP1028     Tilai Bao   26            Clothing
# 299  201803038    VVIP1028     Tilai Bao   26            Clothing
# 300  201801022    VVIP1032        Pengli   28            Clothing
# 301  201802098    VVIP1035       Li Cong   33            Clothing
# 302  201803065    VVIP1036        Du Wei   34               Shoes
# 305  201802021    VVIP1037       Yang Yi   31            Cosmetic
# 303  201801099    VVIP1037       Yang Yi   31               Shoes
# 304  201802013    VVIP1037       Yang Yi   31            Cosmetic
# 313  201802101    VVIP1038        Kerina   25            Clothing
# 306  201801010    VVIP1038        Kerina   25            Clothing
# 307  201801070    VVIP1038     Ke Kerina   25            Cosmetic
# 308  201802009    VVIP1038     Ke Kerina   25            Cosmetic
# 309  201802033    VVIP1038     Ke Kerina   25            Clothing
# 310  201802037    VVIP1038     Ke Karina   25            Clothing
# 311  201802058    VVIP1038        Kerina   25            Clothing
# 312  201802065    VVIP1038        Kerina   25            Cosmetic
# 314  201802106    VVIP1038        Kerina   25               Shoes
# 315  201803006    VVIP1038        Kerina   25            Clothing
# 316  201801077    VVIP1042        Philip   27         Accessories
# 317  201801084    VVIP1042       Philips   27         Accessories
# 319  201802066    VVIP1043      Patricia   32            Clothing
# 320  201802067    VVIP1043      Patricia   32            Clothing
# 318  201802007    VVIP1043  Yng Patricia   32         Accessories
# 321  201803114    VVIP1043      Patricia   32            Clothing
# 323  201802096    VVIP1044    Cai Haizhu   29            Clothing
# 322  201801013    VVIP1044    Cai Haizhu   29            Clothing
# 324  201802097    VVIP1044    Cai Haizhu   29            Clothing
# 326  201801007    VVIP1047        Jin Ye   33            Clothing
# 325  201801006    VVIP1047        Jin Ye   33            Clothing
# 327  201802075    VVIP1047        Jin Yu   33            Clothing
#
#                              Brand  \
# 0                      Marc Jacobs
# 1                   Gentle Monster
# 2                   Gentle Monster
# 3                       La Prairie
# 4                   Gentle Monster
# 5                     Alice Olivia
# 6                  Stuart Weitzman
# 13                     Club Monaco
# 12                            Dior
# 11                           Lamer
# 9                            Lamer
# 8                              CPB
# 7                  Stuart Weitzman
# 10                          Armani
# 14                         Tiffany
# 15                    Canada Goose
# 16                            Dior
# 17                             MLB
# 21                            Maje
# 20                            Maje
# 19                            Maje
# 18                            Maje
# 22                             YSL
# 23                           Pinko
# 24                         Redline
# 25                     Marc Jacobs
# 26                          Jbrand
# 27                 Stuart Weitzman
# 28   Lamer/La Prairie/Chantecaille
# 29                      Macy Mcooy
# ..                             ...
# 298                    Club Monaco
# 299                    Club Monaco
# 300                          Coach
# 301                         Sandro
# 302                Stuart Weitzman
# 305                   Chantecaille
# 303                Stuart Weitzman
# 304                   Chantecaille
# 313                     Tory Burch
# 306                           Maje
# 307                       Givenchy
# 308                     La Prairie
# 309                         Theory
# 310                         Armani
# 311                         Adidas
# 312                  Louis Vuitton
# 314                     Tory Burch
# 315                    Club Monaco
# 316                          Coach
# 317                   Roger Vivier
# 319                         Armani
# 320                         Armani
# 318                 Gentle Monster
# 321                     Macy Mcooy
# 323                    Club Monaco
# 322                           Maje
# 324                         Theory
# 326                           Maje
# 325                           Maje
# 327                    Scotch Soda
#
#                                     Product Name      City        Lat  \
# 0          mmj camera crossbody bag   Black grey   Beijing  39.904200
# 1                                    gm madcrush   Beijing  39.904200
# 2                         gm madcrush sunglasses   Beijing  39.904200
# 3                                  lp gift set 2  Hangzhou  30.274084
# 4                         gm sunglasses madcrush   Beijing  39.904200
# 5         alice olivia katz sunburst skirt size0   Beijing  39.904200
# 6             STUART WEITZMAN BOLSHOI SUEDE RED7   Beijing  39.904200
# 13              club monaco Mule Shoes White 365   Beijing  39.904200
# 12                          dior sunglasses blue   Beijing  39.904200
# 11                                lamer gift set   Beijing  39.904200
# 9                              lamer gift set *3   Beijing  39.904200
# 8                        cpb gwp*3 + lamer gwp*1   Beijing  39.904200
# 7                              sw tiemodel Grey7   Beijing  39.904200
# 10                armani Burgundy  Sweatshirt  l   Beijing  39.904200
# 14                tiffany  bracelet red heart *3   Beijing  39.904200
# 15                 Canada Goose long parka m/m/l   Beijing  39.904200
# 16                          dior sunglasses nude   Beijing  39.904200
# 17                         MLB  & Gucci Bee Caps   Beijing  39.904200
# 21                        maje pink maxi dress 2   Beijing  39.904200
# 20         maje long sleeve lace dress   Black 1   Beijing  39.904200
# 19                        maje maxi dress pink 1   Beijing  39.904200
# 18                   maje  Blue  stripe  dress 1   Beijing  39.904200
# 22                                ysl Clutch Red   Beijing  39.904200
# 23             pinko Black signature badge small   Beijing  39.904200
# 24                redline all rope yellow gold l   Beijing  39.904200
# 25            mmj camera crossbody bag rose pink   Beijing  39.904200
# 26   JBrand  Natasha Sky high jeans dark Blue 27   Beijing  39.904200
# 27                      sw MANILA TASSEL BLACK 8   Beijing  39.904200
# 28                 lamer / lp / chantecaille etc   Beijing  39.904200
# 29                     Trmpet Sleeves Black Suit   Beijing  39.904200
# ..                                           ...       ...        ...
# 298                 club  White docpot blouse xs   Beijing  39.904200
# 299                      club borre pants Black2   Beijing  39.904200
# 300                           coach  Black tee s   Beijing  39.904200
# 301                     sandro dress pink lace 3   Beijing  39.904200
# 302               sw simple nude bling heels 5.5   Beijing  39.904200
# 305               Chantecaille eye stress repair   Beijing  39.904200
# 303      STUART WEITZMAN BOLSHOI LEATHER NUDE5.5   Beijing  39.904200
# 304                    Chantecaille diamond mask   Beijing  39.904200
# 313                        tb emma silk blouse 2   Beijing  39.904200
# 306                         maje leather dress 2   Beijing  39.904200
# 307    Givenchy lipstick lamb leather red velvet   Beijing  39.904200
# 308                                lp gift set 3   Beijing  39.904200
# 309                               theory dress 4   Beijing  39.904200
# 310                     ARMANI Sweatshirt  Red m   Beijing  39.904200
# 311                                 adidas tee l   Beijing  39.904200
# 312              lv rose des vent  Perfume 100ml   Beijing  39.904200
# 314                          tb pearl shoes 35.5   Beijing  39.904200
# 315              club manaco Mule Shoes White 36   Beijing  39.904200
# 316                           coach twilly scarf   Beijing  39.904200
# 317                   Roger Viver  Belt  mint 80   Beijing  39.904200
# 319       armani side button ponte dress black m   Beijing  39.904200
# 320                     armani  Red Sweatshirt m   Beijing  39.904200
# 318                        gm madcrushsunglasses   Beijing  39.904200
# 321                    Trmpet Sleeves Black Suit   Beijing  39.904200
# 323       club monaco silk Black floral dress  0   Beijing  39.904200
# 322              maje  Black lace v-neck dress 1   Beijing  39.904200
# 324                              theory  dress 2   Beijing  39.904200
# 326                             maje dress red 1   Beijing  39.904200
# 325               maje short Black puff jacket 1   Beijing  39.904200
# 327                    scotch soda sweater skirt   Beijing  39.904200
#
#            Long Unit Price Price Type  Quantity
# 0    116.407396      $294      median         1
# 1    116.407396      $203      median         1
# 2    116.407396      $203      median         1
# 3    120.155070       $45        low          1
# 4    116.407396      $203      median         1
# 5    116.407396      $594      luxury         1
# 6    116.407396      $155      median         1
# 13   116.407396      $255      median         1
# 12   116.407396      $297      median         1
# 11   116.407396       $56        low          1
# 9    116.407396      $169      median         1
# 8    116.407396      $155      median         1
# 7    116.407396      $155      median         1
# 10   116.407396       $88        low          1
# 14   116.407396      $398       high          1
# 15   116.407396      $896      luxury         3
# 16   116.407396      $305       high          1
# 17   116.407396       $42        low         10
# 21   116.407396      $155      median         1
# 20   116.407396      $155      median         1
# 19   116.407396      $155      median         1
# 18   116.407396      $155      median         1
# 22   116.407396      $155      median         1
# 23   116.407396      $227      median         1
# 24   116.407396      $155      median         1
# 25   116.407396      $289      median         1
# 26   116.407396      $258      median         1
# 27   116.407396      $291      median         1
# 28   116.407396      $153      median         1
# 29   116.407396    $1,703       Group         1
# ..          ...        ...        ...       ...
# 298  116.407396      $192      median         1
# 299  116.407396      $194      median         1
# 300  116.407396      $155      median         1
# 301  116.407396      $559      luxury         1
# 302  116.407396      $367       high          1
# 305  116.407396      $155      median         1
# 303  116.407396      $155      median         1
# 304  116.407396      $155      median         1
# 313  116.407396      $278      median         1
# 306  116.407396      $188      median         1
# 307  116.407396      $155      median         1
# 308  116.407396      $155      median         1
# 309  116.407396      $155      median         1
# 310  116.407396      $155      median         1
# 311  116.407396      $155      median         1
# 312  116.407396      $289      median         1
# 314  116.407396      $325       high          1
# 315  116.407396      $268      median         1
# 316  116.407396      $155      median         1
# 317  116.407396      $155      median         1
# 319  116.407396      $106      median         1
# 320  116.407396       $92        low          1
# 318  116.407396      $155      median         1
# 321  116.407396    $3,406       Group         1
# 323  116.407396      $155      median         1
# 322  116.407396      $169      median         1
# 324  116.407396      $200      median         1
# 326  116.407396      $139      median         1
# 325  116.407396      $180      median         1
# 327  116.407396      $102      median         1
#
# [328 rows x 13 columns]

# %%
# Get List of customers, how many orders per customer, how much products they buy

list_customers = df_dropcols['Customer ID'].unique()
total_orders_customer = df_dropcols.groupby(['Customer ID'])['Order ID'].count()
total_buy_customers = df_dropcols.groupby(['Customer ID'])['Quantity'].sum()

# %%
# Get the age per customer

list_cust_age = []    
for customer in list_customers:
    list_cust_age.append(df_dropcols.loc[df_dropcols['Customer ID'] == customer, 'Age'].iloc[0])

# %%
# Create DataFrame Customers and populate it

df_customers = pd.DataFrame()
df_customers['Customer ID'] = pd.Series(list_customers).values
df_customers['Age'] = pd.Series(list_cust_age).values
df_customers['Total Orders'] = pd.Series(total_orders_customer).values
df_customers['Total Products'] = pd.Series(total_buy_customers).values

df_customers.head(10)
# Out:
#   Customer ID  Age  Total Orders  Total Products
# 0      DL1004   28             5               5
# 1      DL1005   32             2               2
# 2      DL1007   29             7               7
# 3      DL1011   25             1               1
# 4      DL1012   30             3              14
# 5      DL1013   33             4               4
# 6      DL1014   28             2               2
# 7      DL1015   35             4               4
# 8      DL3001   35             1               1
# 9      DL3002   35             1               1

# %%
display(df_customers['Age'].min())
display(df_customers['Age'].max())
# Out:
# 23
# 39

# %%
# Create the bins in which Data will be held
bins = [22, 27, 31, 35, 40]

# Create the names for the four bins
group_age = ['1', '2', '3', '4']

df_customers["Group Age"] = pd.cut(df_customers["Age"], bins, labels=group_age)
df_customers.head(10)
# Out:
#   Customer ID  Age  Total Orders  Total Products Group Age
# 0      DL1004   28             5               5         2
# 1      DL1005   32             2               2         3
# 2      DL1007   29             7               7         2
# 3      DL1011   25             1               1         1
# 4      DL1012   30             3              14         2
# 5      DL1013   33             4               4         3
# 6      DL1014   28             2               2         2
# 7      DL1015   35             4               4         3
# 8      DL3001   35             1               1         3
# 9      DL3002   35             1               1         3

# %%
stats = df_customers.describe()
stats
# Out:
#               Age  Total Orders  Total Products
# count  186.000000    186.000000      186.000000
# mean    30.397849      1.763441        1.822581
# std      4.241723      1.527392        1.769326
# min     23.000000      1.000000        1.000000
# 25%     27.000000      1.000000        1.000000
# 50%     31.000000      1.000000        1.000000
# 75%     34.000000      2.000000        2.000000
# max     39.000000     10.000000       14.000000

# %%
f1 = df_customers['Group Age'].values
f2 = df_customers['Total Products'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)

# %%
from sklearn.cluster import KMeans
Nc = range(1, 6)

kmeans = [KMeans(n_clusters=i) for i in Nc]

score = [kmeans[i].fit(Y).score(Y) for i in range(len(kmeans))]

pl.plot(Nc,score)

pl.xlabel('Number of Clusters')

pl.ylabel('Score')

pl.title('Elbow Curve')

pl.show()

# %%
# Fitting the input data
kmeans=KMeans(n_clusters=4)

kmeans = kmeans.fit(X)

# %%
# Predict the clusters
predicted_clusters = kmeans.predict(X)

# %%
kmeansoutput=kmeans.fit(Y)
kmeansoutput
pl.figure('4 Cluster K-Means')
# Plot the predicted clusters to see if the model predicted the correct clusters
# This is visual validation that the model was trained correctly.
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
#pl.scatter(pca_c[:, 0], pca_d[:, 0], c=kmeansoutput.labels_)
pl.xlabel('Group Age')
pl.ylabel('Total Products')
pl.title('4 Cluster K-Means')

pl.show()
